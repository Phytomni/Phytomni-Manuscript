# %%
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
import plotly.offline as offline

# %%
offline.init_notebook_mode(connected=True)
pio.kaleido.scope.default_format = 'pdf'

# %%
x = [0, 1, 3, 6, 12, 18, 24]
x_rev = x[::-1]
yas = [0, 0.044217687,	0.06122449,	0.105442177,	0.108843537,	0.108843537,	0.108843537]
yas1 = [0, 0,	0.017006803,	0.163265306,	0.163265306,	0.163265306,	0.25170068]
yas2 = [0, 0.030612245,	0.044217687,	0.088435374,	0.142857143,	0.176870748,	0.234693878]

ycr = [0, 0.585585586,	0.585585586,	0.585585586,	0.585585586,	0.585585586,	0.648648649]
ycr1 = [0, 0,	0,	0.027027027,	0.09009009,	0.135135135,	0.234234234]
ycr2 = [0, 0,	0.045045045,	0.09009009,	0.09009009,	0.234234234,	0.261261261]

ymp = [0, 0.030351438,	0.095846645,	0.107028754,	0.11341853,	0.11341853,	0.11341853]
ymp1 = [0, 0.030351438,	0.073482428,	0.118210863,	0.145367412,	0.151757188,	0.177316294]
ymp2 = [0, 0.030351438,	0.161341853,	0.348242812,	0.353035144,	0.353035144,	0.452076677]

yng = [0, 0.144230769,	0.144230769,	0.144230769,	0.144230769,	0.144230769,	0.144230769]
yng1 = [0, 0.009615385,	0.019230769,	0.019230769,	0.355769231,	0.365384615,	0.403846154]
yng2 = [0, 0,	0.057692308,	0.057692308,	0.221153846,	0.221153846,	0.221153846]

ypc = [0, 0.229357798,	0.256880734,	0.293577982,	0.316513761,	0.316513761,	0.316513761]
ypc1 = [0, 0,	0,	0.101694915,	0.131355932,	0.131355932,	0.131355932]
ypc2 = [0, 0,	0,	0.127118644,	0.148305085,	0.156779661,	0.169491525]

# %%
line_width = 2

y_p_list = [ymp, yas, ycr, yng, ypc]
color_p_list = ['#82B366', '#D6B656', '#9673A6', '#6C8EBF', '#B85450']
name_list = ['developmental biology', 'trait mechanisms', 'epigenetics', 'integrated omics analysis', 'synthetic biology']
y_h1_list = [ymp1, yas1, ycr1, yng1, ypc1]
y_h2_list = [ymp2, yas2, ycr2, yng2, ypc2]
color_h_list = ['#D5E8D4', '#FFF2CC', '#E1D5E7', '#DAE8FC', '#F8CECC']
alpha = ['a', 'b', 'c', 'd', 'e']
paper_list = ['mp', 'as', 'cr', 'ng', 'pc']

for i in range(5):
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=x,
        y=y_h1_list[i],
        line_color=color_h_list[i],
        line_width=line_width,
        marker={'size': 20},
        showlegend=False,
        name=f'Human-1 - {name_list[i]}',
    ))
    fig.add_trace(go.Scatter(
        x=x,
        y=y_h2_list[i],
        line_color=color_h_list[i],
        line_width=line_width,
        marker={'size': 20},
        showlegend=False,
        name=f'Human-1 - {name_list[i]}',
    ))
    fig.add_trace(go.Scatter(
        x=x, y=y_p_list[i],
        line_color=color_p_list[i],
        line_width=line_width,
        marker={'size': 20},
        showlegend=False,
        name=f'Phytomni - {name_list[i]}',
    ))

    fig.update_layout(
        xaxis={'showline': True, 'linewidth': line_width, 'linecolor': 'rgb(0,0,0)', 'mirror': True, 'ticks': 'outside', 'tickwidth': line_width, 'title_text': 'Work time (hours)', 'dtick': 1, 'range': [0, 24]},
        yaxis={'showline': True, 'linewidth': line_width, 'linecolor': 'rgb(0,0,0)', 'mirror': True, 'ticks': 'outside', 'tickwidth': line_width, 'title_text': 'Replication score', 'range': [0, 1]},
        plot_bgcolor='white',
        font_family='Arial',
        font_color='rgb(0,0,0)',
        font_size=20,
        width=1920,
        height=1920*26/5/18.4)
    fig.update_traces(mode='lines+markers')

    fig.show()
    # file_prefix = f'supplementary_fig.6{alpha[i]}.model.paperbench-{paper_list[i]}.line'.lower().replace(' ', '_')
    # fig.write_image(f'{file_prefix}.pdf')
    # fig.write_image(f'{file_prefix}.png')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
